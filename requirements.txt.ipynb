# %%
streamlit
pandas
numpy
scikit-learn
pickle-mixin
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 streamlit
#       2 pandas
#       3 numpy
#
# NameError: name 'streamlit' is not defined
